# %%
from ultralytics import YOLO
model=YOLO('yolov8s-pose.pt')
# Out:
# ...
# 100%|██████████| 22.4M/22.4M [00:02<00:00, 9.30MB/s]

# %%
model.predict("C:/Users/anil.nagamunthala/OneDrive/Pictures/image mine 2.JPG")
# Out:
# image 1/1 C:\Users\anil.nagamunthala\OneDrive\Pictures\image mine 2.JPG: 640x480 1 person, 817.4ms
# Speed: 31.2ms preprocess, 817.4ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[102, 121, 134],
#          [ 89, 109, 120],
#          [ 88, 112, 118],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[112, 131, 146],
#          [109, 128, 141],
#          [107, 130, 138],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[119, 137, 154],
#          [124, 143, 158],
#          [121, 143, 155],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
# ...

# %%
#model.predict("C:/Users/anil.nagamunthala/Downloads/Video sample for YOLO object detection.mp4")

# %%
import cv2
cap=cv2.VideoCapture(0)
if not cap.isOpened():
    print('webcam openening error')
    exit()
while cap.isOpened():
    rti,frame=cap.read()
    if not rti:
        print('frames error')
        break
    results=model.predict(frame)
    frame_width=results[0].plot()
    cv2.imshow('webcam segmentation',frame_width)
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 893.0ms
# Speed: 0.0ms preprocess, 893.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 557.0ms
# Speed: 10.1ms preprocess, 557.0ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 569.5ms
# Speed: 16.2ms preprocess, 569.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 549.8ms
# Speed: 6.5ms preprocess, 549.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 522.1ms
# Speed: 7.0ms preprocess, 522.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 597.5ms
# Speed: 6.9ms preprocess, 597.5ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 547.1ms
# Speed: 3.8ms preprocess, 547.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 772.0ms
# ...
